# %%
import pandas as pd
from tensorflow import keras
import numpy as np

# %%
orig_data = pd.read_csv("data_set/从11个特征预测学生的测试分数.csv")
orig_data
# Out:
#      school school_setting school_type classroom teaching_method  n_student  \
# 0     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4     ANKYI          Urban  Non-public       6OL        Standard       20.0
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2129  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2130  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2131  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2132  ZOWMK          Urban      Public       ZBH        Standard       30.0
#
# ...

# %%
X , Y = orig_data.iloc[:,0:9] , orig_data.iloc[:,10] #切片

# %%
X = X.drop(columns=["school","classroom","student_id","	teaching_method	"],axis=1)#按列丢弃无关项

# %%
X
# Out:
#      school_setting school_type teaching_method  n_student  gender  \
# 0             Urban  Non-public        Standard       20.0  Female
# 1             Urban  Non-public        Standard       20.0  Female
# 2             Urban  Non-public        Standard       20.0    Male
# 3             Urban  Non-public        Standard       20.0  Female
# 4             Urban  Non-public        Standard       20.0    Male
# ...             ...         ...             ...        ...     ...
# 2128          Urban      Public        Standard       30.0  Female
# 2129          Urban      Public        Standard       30.0  Female
# 2130          Urban      Public        Standard       30.0  Female
# 2131          Urban      Public        Standard       30.0    Male
# 2132          Urban      Public        Standard       30.0    Male
#
#                                  lunch
# 0                     Does not qualify
# 1                     Does not qualify
# 2                     Does not qualify
# ...

# %%
X = pd.get_dummies(X,columns=["school_setting","school_setting","teaching_method","gender","lunch"],dtype=int)

# %%
X
# Out:
#      school_type  n_student  school_setting_Rural  school_setting_Suburban  \
# 0     Non-public       20.0                     0                        0
# 1     Non-public       20.0                     0                        0
# 2     Non-public       20.0                     0                        0
# 3     Non-public       20.0                     0                        0
# 4     Non-public       20.0                     0                        0
# ...          ...        ...                   ...                      ...
# 2128      Public       30.0                     0                        0
# 2129      Public       30.0                     0                        0
# 2130      Public       30.0                     0                        0
# 2131      Public       30.0                     0                        0
# 2132      Public       30.0                     0                        0
#
# ...
